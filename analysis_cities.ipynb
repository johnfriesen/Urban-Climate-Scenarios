# %%
import pandas as pd

# Replace 'cities.csv' with your actual CSV file name or path.
df = pd.read_csv('cities_temp_diff_data_SSP5.csv', encoding='utf-8')

# Filter rows for European cities
europe_cities = df[df['Continent'] == 'Europe']

# Sort by 'Mean_2071_2100' in descending order and select the top 10 rows
top10_europe = europe_cities.sort_values(by='Temp_Diff_2071_2100', ascending=False).head(60)

print(top10_europe)
# Out:
#                                     City  Mean_1981_2010  Mean_2071_2100  \
# 1488                             Yakutsk       -8.734411       -2.731031
# 1288                              Surgut       -1.873646        4.048477
# 90                           Arkhangelsk        1.512077        7.236111
# 1358                               Tomsk        0.810056        6.513503
# 986                          Novosibirsk        1.572541        7.251720
# 1002                                Omsk        1.958435        7.614402
# 149                              Barnaul        2.686199        8.283598
# 688                             Kemerovo        1.522145        7.077199
# 1381                              Tyumen        2.040485        7.284141
# 723                          Krasnoyarsk        1.431078        6.665690
# 734                               Kurgan        2.917173        8.144467
# 936                  Naberezhnye Tchelny        3.999833        9.193266
# ...
